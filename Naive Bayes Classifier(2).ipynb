# %%
import pandas as pd
dataset = pd.read_csv("Naive bayes dataset.csv")
# Assign X and y
X = dataset["Text"]
y = dataset["Label"]

# Train-test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0, stratify=y)
# Convert text into numerical features
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X_train = cv.fit_transform(X_train)
X_test = cv.transform(X_test) 
# Import Naive Bayes model
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
# Train model
nb.fit(X_train, y_train)
# Predict
y_pred = nb.predict(X_test) 
# Evaluate accuracy
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy) 
print("Actual:", y_test.values)
print("Predicted:", y_pred)
# Test with new sentence
sample = ["This product is amazing"]
sample_vector = cv.transform(sample)
prediction = nb.predict(sample_vector)
print("Prediction:", prediction)
# Out:
# Accuracy: 0.6666666666666666
# Actual: ['Positive' 'Negative' 'Positive' 'Positive' 'Negative' 'Positive'
#  'Negative' 'Positive' 'Positive' 'Positive' 'Negative' 'Negative'
#  'Negative' 'Negative' 'Negative']
# Predicted: ['Negative' 'Negative' 'Positive' 'Negative' 'Positive' 'Positive'
#  'Negative' 'Positive' 'Positive' 'Positive' 'Negative' 'Positive'
#  'Negative' 'Positive' 'Negative']
# Prediction: ['Negative']
